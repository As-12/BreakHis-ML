# %% [markdown]
# # MLP-CW4 Experiment 3 200x  execution notebook
#
# This notebook is not for data exploration. But to log execution of experiments.
# This job runs baseline 5 times and save results to files/

# %% [markdown]
# ## Imports

# %%
# set the matplotlib backend so figures can be saved in the background
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import matplotlib
import keras
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2

import shutil
import fnmatch
import pickle
from keras import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Input
from keras.constraints import max_norm
from keras import regularizers
from keras.layers.advanced_activations import LeakyReLU
import keras.initializers
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import keras.optimizers
from keras.utils import np_utils
from keras import backend as K
from keras.applications.inception_v3 import InceptionV3

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
# Out:
# /home/as12production/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Environment Settings

# %%
#Keras setting
K.set_image_dim_ordering('tf')  #Image dimension ordering

#Random seeds
SEED = 2082018
np.random.seed(SEED)

#Image Settings
IMAGE_RESIZE = (224,224)  # Image size. Process on the by data generator. Should match CNN model input. 
IMAGE_INPUT_SIZE = (224,224,3) #Image Input size to the neural network

#Training Settings
BATCH_SIZE = 32
EPOCH = 20

#Directories
# NOTE: The labels are determined by subfolders. PNG or JPEG images only.
TRAIN_DIR = '../TRAIN' 
VAL_DIR = '../VALID'
TEST_DIR =  '../TEST'


#["-40","-100-","-200-","-400-"]
magnifications = "-200-"


#Index of the class label represents numerical representation
CLASS_LABELS = ["Benign", "Malignant"]
NUM_CLASSES = 2
#Checkpoints and save files

#Saving every epochs that improve val accuracy
#MODEL_CHECKPOINT_FILE="baseline_model-weights-{epoch:02d}-{val_acc:.2f}.hdf5"
# Rewriting save file for epoch that improves val accuracy
MODEL_CHECKPOINT_FILE="inception3-weights.hdf5"  

#Training charts and graphics
MODEL_TRAIN_RESULTS_FILE="inception3_train.pickle"
MODEL_ACCURACY_GRAPH_FILE="inception3_accuracy.pdf"
MODEL_LOSS_GRAPH_FILE="inception3_loss.pdf"
MODEL_EVALUATION_CM_FILE="inception3_CM.pdf"

# %% [markdown]
# ## Loading Dataset

# %%
def buildImageDataset(path, imageResize=None,shuffle=False,seed=0):
    """
    Load dataset into an array. Labels are defined by folder name.
    """
    filenames = []
    data = []
    labels = []
    imagePaths = sorted(list(paths.list_images(path)))
    
    if shuffle == True:
        random.seed(seed)
        random.shuffle(imagePaths)

    for imagePath in imagePaths:
        image = cv2.imread(imagePath)
        if imageResize != None:
            image = cv2.resize(image, imageResize)
        image = img_to_array(image)
        data.append(image)
        filenames.append(imagePath)
        label = imagePath.split(os.path.sep)[-2]
        labels.append(CLASS_LABELS.index(label))
    return (np.array(data), np.array(labels), np.array(filenames))

def showClassDistribution(y, labels):
    figure = plt.figure(figsize=(10,5))
    ax = sns.countplot(x = y)
    ax.set_xticklabels(labels)
    plt.show()

# %%
run_this = 1

# Load and save
if run_this == 1:
    X_train, y_train, train_files = buildImageDataset(TRAIN_DIR,imageResize=IMAGE_RESIZE,seed=SEED)
    X_valid, y_valid, valid_files = buildImageDataset(VAL_DIR,imageResize=IMAGE_RESIZE,seed=SEED)
    
    with open("X_train.pickle", "wb") as output_file:
            pickle.dump(X_train, output_file)

    with open("y_train.pickle", "wb") as output_file:
            pickle.dump(y_train, output_file)

    with open("X_valid.pickle", "wb") as output_file:
            pickle.dump(X_valid, output_file)

    with open("y_valid.pickle", "wb") as output_file:
            pickle.dump(y_valid, output_file)
    
            
# Quick load from saved files
if run_this == 2:
    X_train = pickle.load( open( "X_train.pickle", "rb" ) )
    y_train = pickle.load( open( "y_train.pickle", "rb" ) )
    X_valid = pickle.load( open( "X_valid.pickle", "rb" ) )
    y_valid = pickle.load( open( "y_valid.pickle", "rb" ) )

# %%
run_this = 1

if run_this == 1:
    validDataFrame = pd.DataFrame({'label':y_valid, 'filename':valid_files})
    trainDataFrame = pd.DataFrame({'label':y_train, 'filename':train_files})
    
    index = [i for i,item in enumerate(trainDataFrame["filename"]) if magnifications in item]
    X_train = X_train[index]
    y_train = y_train[index]
    train_files = train_files[index]
    
    index = [i for i,item in enumerate(validDataFrame["filename"]) if magnifications in item]
    X_valid = X_valid[index]
    y_valid = y_valid[index]
    valid_files = valid_files[index]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(X_train[-1])
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(X_train[1])
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(X_valid[-1])
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(X_valid[1])

fig.savefig("200x_rescaled_images.pdf")

# %%
trainDataFrame = pd.DataFrame({'label':y_train, 'filename':train_files})
showClassDistribution(y_train, CLASS_LABELS)
print("There are {} items in training set.".format(len(y_train) ))
# Out:
# There are 1325 items in training set.

# %%
validDataFrame = pd.DataFrame({'label':y_valid, 'filename':valid_files})
showClassDistribution(y_valid, CLASS_LABELS)
print("There are {} items in validation set.".format(len(y_valid) ))
# Out:
# There are 467 items in validation set.

# %% [markdown]
# ## Pre-Processing

# %%
X_train /= 255.0
X_valid /= 255.0
y_train = keras.utils.to_categorical(y_train)
y_valid = keras.utils.to_categorical(y_valid)

# %% [markdown]
# # Building Neural Net Model

# %%
# Building Models
def InceptionNet():
    #https://keras.io/applications/#inceptionv3
    #Use Inception 3 without the last layer.
    #Replace last layer with 1 sigmoid for binary classification
    sgd = SGD(lr=0.01, momentum=0.9,nesterov=False)
    model = keras.applications.inception_v3.InceptionV3(include_top=False,
                                                        weights='imagenet',  #Pre-train on ImageNet 
                                                        input_tensor=Input(shape=IMAGE_INPUT_SIZE),
                                                        input_shape=None,
                                                        pooling='avg',
                                                        classes=NUM_CLASSES)
    final = Model(input=model.input,output=Dense(NUM_CLASSES, activation='softmax')(model.output))
    final.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])    
    return final

# %% [markdown]
# # Required Function Definitions

# %%
def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    plot = plt.figure()
    if classes is not None:
        sns.heatmap(cm, xticklabels=classes, yticklabels=classes, vmin=0., vmax=1., annot=True)
    else:
        sns.heatmap(cm, vmin=0., vmax=1.)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    return plot

# %%
def generateTrainingPlots(history, accuracy_grap_file, loss_graph_file):
    plt.style.use('ggplot')
    accuracy_plot = plt.figure(figsize=(15,10))
    for k in ['val_acc', 'acc']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch Number')
    plt.ylim((0,1.2))
    plt.legend(['acc(valid)', 'acc(train)'], loc='upper left')
    plt.grid(True)
    plt.show()
    loss_plot = plt.figure(figsize=(15,10))
    for k in ['loss', 'val_loss']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Loss')
    plt.ylabel('Error (Log Loss)')
    plt.xlabel('Epoch Number')
    plt.grid(True)
    plt.legend(['error(train)', 'error(valid)'], loc='upper left')
    plt.show()
    #Save visualization data    
    accuracy_plot.savefig(accuracy_grap_file, bbox_inches='tight')
    loss_plot.savefig(loss_graph_file, bbox_inches='tight')

# %%
def evaluateClassifier(history, classifier, weights, X ,y , cm_file, out_file, classlabels):
    classifier.load_weights(weights)
    y_pred = classifier.predict(X)
    cm = confusion_matrix(np.argmax(y,axis=1), np.argmax(np.rint(y_pred),axis=1))
    cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]
    plot = plot_confusion_matrix(cm_norm, classes=classlabels)
    plot.savefig(cm_file, bbox_inches='tight')
    scores = classifier.evaluate(X_valid,y_valid)
    with open(out_file, 'w') as the_file:
        the_file.write("Max Val Acc: " + str(np.max(np.array(history['val_acc']))))
        the_file.write("\nMin Val Acc: " + str(np.min(np.array(history['val_acc']))))
        the_file.write("\nMax Train Acc: "  + str(np.max(np.array(history['acc']))))
        the_file.write("\nMin Train Acc: "  + str(np.min(np.array(history['acc']))))
        the_file.write("\nMax Val Err: "  + str(np.max(np.array(history['val_loss']))))
        the_file.write("\nMin Val Err: " + str(np.min(np.array(history['val_loss']))))
        the_file.write("\nMax Train Err: " + str(np.max(np.array(history['loss']))))
        the_file.write("\nMin Train Err: " +  str(np.min(np.array(history['loss']))))
        the_file.write("\nResult: " + str(scores))
        the_file.write("\nResult: " +  str(model.metrics_names))

# %% [markdown]
# # Training & Visualizing & Evaluating

# %%
for i in range(1,4):
    print("Running Experiment Iteration",i)
    model = InceptionNet()
    #Process filenames
    prefix = "run#{}_".format(i)
    MODEL_CHECKPOINT_FILE=prefix + "experiment3"+magnifications+"inception3-weights.hdf5"  
    #Training charts and graphics
    MODEL_TRAIN_RESULTS_FILE=prefix + "experiment3"+magnifications+"inception3_train.pickle"
    MODEL_ACCURACY_GRAPH_FILE=prefix + "experiment3"+magnifications+"inception3_accuracy.pdf"
    MODEL_LOSS_GRAPH_FILE=prefix + "experiment3"+magnifications+"inception3_loss.pdf"
    MODEL_EVALUATION_CM_FILE=prefix + "experiment3"+magnifications+"inception3_CM.pdf"
    MODEL_EVALUATION_TEXT_FILE=prefix + "experiment3"+magnifications+"inception3_eval.txt"
    
    checkpoint = ModelCheckpoint(MODEL_CHECKPOINT_FILE, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    #Training
    history = model.fit(x=X_train,y=y_train,
                        validation_data=(X_valid,y_valid),
                        batch_size=BATCH_SIZE,
                        epochs = EPOCH,
                        callbacks = callbacks_list)
    
    #Saving training result
    with open(MODEL_TRAIN_RESULTS_FILE, "wb") as output_file:
        pickle.dump(history.history, output_file)    
    
    #Generate training graphs
    generateTrainingPlots(history.history, MODEL_ACCURACY_GRAPH_FILE, MODEL_LOSS_GRAPH_FILE)
    
    #evaluate classifier
    evaluateClassifier(history.history, InceptionNet(), MODEL_CHECKPOINT_FILE, 
                       X_valid ,y_valid , MODEL_EVALUATION_CM_FILE, MODEL_EVALUATION_TEXT_FILE, CLASS_LABELS)
    del model
# Out:
# Running Experiment Iteration 1
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 1325 samples, validate on 467 samples
# Epoch 1/20
# 1325/1325 [==============================] - 40s 31ms/step - loss: 0.3178 - acc: 0.8702 - val_loss: 1.6008 - val_acc: 0.6017
#
# Epoch 00001: val_acc improved from -inf to 0.60171, saving model to run#1_experiment3-200-inception3-weights.hdf5
# Epoch 2/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.1957 - acc: 0.9358 - val_loss: 1.7496 - val_acc: 0.6210
#
# Epoch 00002: val_acc improved from 0.60171 to 0.62099, saving model to run#1_experiment3-200-inception3-weights.hdf5
# Epoch 3/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.1094 - acc: 0.9668 - val_loss: 2.7556 - val_acc: 0.6938
#
# Epoch 00003: val_acc improved from 0.62099 to 0.69379, saving model to run#1_experiment3-200-inception3-weights.hdf5
# Epoch 4/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0434 - acc: 0.9887 - val_loss: 1.6791 - val_acc: 0.7687
#
# Epoch 00004: val_acc improved from 0.69379 to 0.76874, saving model to run#1_experiment3-200-inception3-weights.hdf5
# Epoch 5/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0248 - acc: 0.9909 - val_loss: 1.3859 - val_acc: 0.7602
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0256 - acc: 0.9925 - val_loss: 1.5749 - val_acc: 0.7473
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0228 - acc: 0.9955 - val_loss: 0.9726 - val_acc: 0.8180
#
# Epoch 00007: val_acc improved from 0.76874 to 0.81799, saving model to run#1_experiment3-200-inception3-weights.hdf5
# Epoch 8/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0058 - acc: 0.9977 - val_loss: 1.4332 - val_acc: 0.7944
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0050 - acc: 0.9985 - val_loss: 1.5505 - val_acc: 0.7773
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0141 - acc: 0.9962 - val_loss: 1.2767 - val_acc: 0.8030
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0059 - acc: 0.9992 - val_loss: 1.1958 - val_acc: 0.7859
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 1.3207 - val_acc: 0.7730
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0071 - acc: 0.9977 - val_loss: 1.1381 - val_acc: 0.7966
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0302 - acc: 0.9925 - val_loss: 1.9866 - val_acc: 0.7430
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0195 - acc: 0.9940 - val_loss: 1.0927 - val_acc: 0.7559
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0585 - acc: 0.9796 - val_loss: 1.1906 - val_acc: 0.7901
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0591 - acc: 0.9842 - val_loss: 1.6050 - val_acc: 0.7730
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0133 - acc: 0.9962 - val_loss: 1.3342 - val_acc: 0.7773
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0050 - acc: 0.9985 - val_loss: 1.6404 - val_acc: 0.7602
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0033 - acc: 0.9992 - val_loss: 1.0482 - val_acc: 0.8073
#
# Epoch 00020: val_acc did not improve
# 467/467 [==============================] - 5s 11ms/step
# Running Experiment Iteration 2
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 1325 samples, validate on 467 samples
# Epoch 1/20
# 1325/1325 [==============================] - 41s 31ms/step - loss: 0.3462 - acc: 0.8581 - val_loss: 0.8140 - val_acc: 0.6617
#
# Epoch 00001: val_acc improved from -inf to 0.66167, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 2/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.1623 - acc: 0.9351 - val_loss: 1.3057 - val_acc: 0.5953
#
# Epoch 00002: val_acc did not improve
# Epoch 3/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0573 - acc: 0.9826 - val_loss: 0.8444 - val_acc: 0.7623
#
# Epoch 00003: val_acc improved from 0.66167 to 0.76231, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 4/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0697 - acc: 0.9789 - val_loss: 2.4098 - val_acc: 0.6916
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0508 - acc: 0.9811 - val_loss: 0.8785 - val_acc: 0.7773
#
# Epoch 00005: val_acc improved from 0.76231 to 0.77730, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 6/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0363 - acc: 0.9902 - val_loss: 1.5111 - val_acc: 0.7794
#
# Epoch 00006: val_acc improved from 0.77730 to 0.77944, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 7/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0436 - acc: 0.9842 - val_loss: 1.4632 - val_acc: 0.7709
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0269 - acc: 0.9902 - val_loss: 1.2861 - val_acc: 0.7837
#
# Epoch 00008: val_acc improved from 0.77944 to 0.78373, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 9/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0117 - acc: 0.9962 - val_loss: 1.5352 - val_acc: 0.7452
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0064 - acc: 0.9985 - val_loss: 1.0274 - val_acc: 0.8051
#
# Epoch 00010: val_acc improved from 0.78373 to 0.80514, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 11/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0013 - acc: 1.0000 - val_loss: 0.9489 - val_acc: 0.8073
#
# Epoch 00011: val_acc improved from 0.80514 to 0.80728, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 12/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 1.0738 - val_acc: 0.8094
#
# Epoch 00012: val_acc improved from 0.80728 to 0.80942, saving model to run#2_experiment3-200-inception3-weights.hdf5
# Epoch 13/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0069 - acc: 0.9985 - val_loss: 1.1987 - val_acc: 0.7752
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.1016 - acc: 0.9592 - val_loss: 1.2731 - val_acc: 0.7366
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0296 - acc: 0.9902 - val_loss: 1.2079 - val_acc: 0.7452
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0173 - acc: 0.9947 - val_loss: 1.0325 - val_acc: 0.8030
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0111 - acc: 0.9962 - val_loss: 1.5641 - val_acc: 0.7687
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.4354 - val_acc: 0.7923
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 1.2741 - val_acc: 0.8051
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 1.3381 - val_acc: 0.8094
#
# Epoch 00020: val_acc improved from 0.80942 to 0.80942, saving model to run#2_experiment3-200-inception3-weights.hdf5
# 467/467 [==============================] - 7s 14ms/step
# Running Experiment Iteration 3
# Train on 1325 samples, validate on 467 samples
# Epoch 1/20
# 1325/1325 [==============================] - 45s 34ms/step - loss: 0.3514 - acc: 0.8506 - val_loss: 3.1222 - val_acc: 0.3854
#
# Epoch 00001: val_acc improved from -inf to 0.38544, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 2/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.1224 - acc: 0.9540 - val_loss: 1.7920 - val_acc: 0.7088
#
# Epoch 00002: val_acc improved from 0.38544 to 0.70878, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 3/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0661 - acc: 0.9781 - val_loss: 1.1328 - val_acc: 0.7323
#
# Epoch 00003: val_acc improved from 0.70878 to 0.73233, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 4/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0345 - acc: 0.9887 - val_loss: 0.7154 - val_acc: 0.8073
#
# Epoch 00004: val_acc improved from 0.73233 to 0.80728, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 5/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0163 - acc: 0.9962 - val_loss: 0.9632 - val_acc: 0.8009
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0133 - acc: 0.9985 - val_loss: 0.7973 - val_acc: 0.7966
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0057 - acc: 0.9970 - val_loss: 1.2219 - val_acc: 0.8051
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0167 - acc: 0.9932 - val_loss: 1.5222 - val_acc: 0.7794
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0379 - acc: 0.9902 - val_loss: 0.8776 - val_acc: 0.8180
#
# Epoch 00009: val_acc improved from 0.80728 to 0.81799, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 10/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0310 - acc: 0.9887 - val_loss: 2.8699 - val_acc: 0.6660
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0391 - acc: 0.9857 - val_loss: 1.0837 - val_acc: 0.7880
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0111 - acc: 0.9955 - val_loss: 0.9622 - val_acc: 0.8458
#
# Epoch 00012: val_acc improved from 0.81799 to 0.84582, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 13/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0033 - acc: 0.9985 - val_loss: 1.1647 - val_acc: 0.8351
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0023 - acc: 0.9992 - val_loss: 1.0265 - val_acc: 0.8544
#
# Epoch 00014: val_acc improved from 0.84582 to 0.85439, saving model to run#3_experiment3-200-inception3-weights.hdf5
# Epoch 15/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0026 - acc: 0.9992 - val_loss: 1.4448 - val_acc: 0.7816
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0037 - acc: 0.9992 - val_loss: 0.9464 - val_acc: 0.8437
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0027 - acc: 0.9985 - val_loss: 1.1897 - val_acc: 0.8137
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 7.3925e-04 - acc: 1.0000 - val_loss: 1.1989 - val_acc: 0.8094
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 9.1432e-04 - acc: 1.0000 - val_loss: 1.1092 - val_acc: 0.8201
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 1325/1325 [==============================] - 32s 24ms/step - loss: 0.0016 - acc: 0.9992 - val_loss: 1.3287 - val_acc: 0.8308
#
# Epoch 00020: val_acc did not improve
# 467/467 [==============================] - 9s 18ms/step

# %%
print("Completed")
# Out:
# Completed
