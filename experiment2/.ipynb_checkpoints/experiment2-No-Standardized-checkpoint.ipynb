# %% [markdown]
# # MLP-CW4 Baseline execution notebook
#
# This notebook is not for data exploration. But to log execution of experiments.
# This job runs baseline 5 times and save results to files/

# %% [markdown]
# ## Imports

# %%
# set the matplotlib backend so figures can be saved in the background
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import matplotlib
import keras
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2

import shutil
import fnmatch
import pickle
from keras import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Input
from keras.constraints import max_norm
from keras import regularizers
from keras.layers.advanced_activations import LeakyReLU
import keras.initializers
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import keras.optimizers
from keras.utils import np_utils
from keras import backend as K
from keras.applications.inception_v3 import InceptionV3

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
# Out:
# /home/as12production/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Environment Settings

# %%
#Keras setting
K.set_image_dim_ordering('tf')  #Image dimension ordering

#Random seeds
SEED = 2082018
np.random.seed(SEED)

#Image Settings
IMAGE_RESIZE = (224,224)  # Image size. Process on the by data generator. Should match CNN model input. 
IMAGE_INPUT_SIZE = (224,224,3) #Image Input size to the neural network

#Training Settings
BATCH_SIZE = 32
EPOCH = 20

#Directories
# NOTE: The labels are determined by subfolders. PNG or JPEG images only.
TRAIN_DIR = '../TRAIN' 
VAL_DIR = '../VALID'
TEST_DIR =  '../TEST'

#Index of the class label represents numerical representation
CLASS_LABELS = ["Benign", "Malignant"]
NUM_CLASSES = 2

# %% [markdown]
# ## Loading Dataset

# %%
def buildImageDatasetGrayScale(path, imageResize=None,shuffle=False,seed=0):
    """
    Load dataset into an array. Labels are defined by folder name.
    
    ** Grayscale **
    """
    filenames = []
    data = []
    labels = []
    imagePaths = sorted(list(paths.list_images(path)))
    
    if shuffle == True:
        random.seed(seed)
        random.shuffle(imagePaths)
        
    for imagePath in imagePaths:
        image = cv2.imread(imagePath)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        image = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)
        if imageResize != None:
            image = cv2.resize(image, imageResize)
        image = img_to_array(image)
        data.append(image)
        filenames.append(imagePath)
        label = imagePath.split(os.path.sep)[-2]
        labels.append(CLASS_LABELS.index(label))
    return (np.array(data), np.array(labels), np.array(filenames))

# %%
run_this = 0

if run_this == 1:
    X_train, y_train, _ = buildImageDatasetGrayScale(TRAIN_DIR,imageResize=IMAGE_RESIZE,seed=SEED)
    X_valid, y_valid, _ = buildImageDatasetGrayScale(VAL_DIR,imageResize=IMAGE_RESIZE,seed=SEED)

    with open("X_train.pickle", "wb") as output_file:
            pickle.dump(X_train, output_file)

    with open("y_train.pickle", "wb") as output_file:
            pickle.dump(y_train, output_file)

    with open("X_valid.pickle", "wb") as output_file:
            pickle.dump(X_valid, output_file)

    with open("y_valid.pickle", "wb") as output_file:
            pickle.dump(y_valid, output_file)
else:
    X_train = pickle.load( open( "X_train.pickle", "rb" ) )
    y_train = pickle.load( open( "y_train.pickle", "rb" ) )
    X_valid = pickle.load( open( "X_valid.pickle", "rb" ) )
    y_valid = pickle.load( open( "y_valid.pickle", "rb" ) )

# %% [markdown]
# ## Pre-Processing

# %%
X_train /= 255.0
X_valid /= 255.0
y_train = keras.utils.to_categorical(y_train)
y_valid = keras.utils.to_categorical(y_valid)

# %%
class ImageStandardizer:
    """
    This class standardizer image to zero mean and unit variance
    Normalization is done for each image channel
    """
    def __init__(self, eps=1e-7):
        self._mean = 0
        self._std = 0
        self._ready = False
        self._epsilon = eps # To prevent divide by zero
    
    def fit(self, train):
        self._mean = np.mean(train,axis=(0, 1, 2, 3))
        self._std = np.std(train, axis=(0, 1, 2, 3))
        self._ready = True
    
    def transform(self, data):
        assert self._ready == True, "ImageStandardizer must be initialized before use. Use fit() to initialize."
        return (data - self._mean)/(self._std + self._epsilon)

# %%
#Normalize data to zero mean unit varaince
Standardizer = ImageStandardizer()
Standardizer.fit(X_train)
X_train = Standardizer.transform(X_train)
X_valid = Standardizer.transform(X_valid)

# %%
# Out:
# array([[[ 0.737378  ,  0.737378  ,  0.737378  ],
#         [-0.0043193 , -0.0043193 , -0.0043193 ],
#         [-0.77348685, -0.77348685, -0.77348685],
#         ...,
#         [-0.05925984, -0.05925984, -0.05925984],
#         [-0.993249  , -0.993249  , -0.993249  ],
#         [-1.2130111 , -1.2130111 , -1.2130111 ]],
#
#        [[ 0.7923185 ,  0.7923185 ,  0.7923185 ],
#         [-0.279022  , -0.279022  , -0.279022  ],
#         [-0.25155175, -0.25155175, -0.25155175],
#         ...,
#         [ 0.2703834 ,  0.2703834 ,  0.2703834 ],
#         [-1.0481895 , -1.0481895 , -1.0481895 ],
#         [-1.7624168 , -1.7624168 , -1.7624168 ]],
#
#        [[ 0.40773475,  0.40773475,  0.40773475],
#         [-0.03178957, -0.03178957, -0.03178957],
#         [ 0.435205  ,  0.435205  ,  0.435205  ],
#         ...,
#         [ 0.21544285,  0.21544285,  0.21544285],
#         [-0.7460166 , -0.7460166 , -0.7460166 ],
#         [-1.8173573 , -1.8173573 , -1.8173573 ]],
#
#        ...,
#
#        [[ 0.76484823,  0.76484823,  0.76484823],
#         [ 0.5725564 ,  0.5725564 ,  0.5725564 ],
#         [ 0.10556178,  0.10556178,  0.10556178],
#         ...,
#         [-0.96577877, -0.96577877, -0.96577877],
#         [-0.993249  , -0.993249  , -0.993249  ],
#         [-1.377833  , -1.377833  , -1.377833  ]],
#
#        [[ 1.0670213 ,  1.0670213 ,  1.0670213 ],
#         [ 0.6549672 ,  0.6549672 ,  0.6549672 ],
#         [-0.08673012, -0.08673012, -0.08673012],
#         ...,
#         [-1.1031301 , -1.1031301 , -1.1031301 ],
#         [-1.1580707 , -1.1580707 , -1.1580707 ],
#         [-1.6525357 , -1.6525357 , -1.6525357 ]],
#
#        [[ 1.0395509 ,  1.0395509 ,  1.0395509 ],
#         [ 0.6274969 ,  0.6274969 ,  0.6274969 ],
#         [-0.41637334, -0.41637334, -0.41637334],
#         ...,
#         [-1.1031301 , -1.1031301 , -1.1031301 ],
#         [-1.2130111 , -1.2130111 , -1.2130111 ],
#         [-1.6525357 , -1.6525357 , -1.6525357 ]]], dtype=float32)

# %% [markdown]
# # Building Neural Net Model

# %%
# Building Models
def InceptionNet():
    #https://keras.io/applications/#inceptionv3
    #Use Inception 3 without the last layer.
    #Replace last layer with 1 sigmoid for binary classification
    sgd = SGD(lr=0.01, momentum=0.9,nesterov=False)
    model = keras.applications.inception_v3.InceptionV3(include_top=False,
                                                        weights='imagenet',  #Pre-train on ImageNet 
                                                        input_tensor=Input(shape=IMAGE_INPUT_SIZE),
                                                        input_shape=None,
                                                        pooling='avg',
                                                        classes=NUM_CLASSES)
    final = Model(input=model.input,output=Dense(NUM_CLASSES, activation='softmax')(model.output))
    final.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])    
    return final

# %% [markdown]
# # Required Function Definitions

# %%
def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    plot = plt.figure()
    if classes is not None:
        sns.heatmap(cm, xticklabels=classes, yticklabels=classes, vmin=0., vmax=1., annot=True)
    else:
        sns.heatmap(cm, vmin=0., vmax=1.)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    return plot

# %%
def generateTrainingPlots(history, accuracy_grap_file, loss_graph_file):
    plt.style.use('ggplot')
    accuracy_plot = plt.figure(figsize=(15,10))
    for k in ['val_acc', 'acc']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch Number')
    plt.ylim((0,1))
    plt.legend(['acc(valid)', 'acc(train)'], loc='upper left')
    plt.grid(True)
    plt.show()
    loss_plot = plt.figure(figsize=(15,10))
    for k in ['loss', 'val_loss']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Loss')
    plt.ylabel('Error (Log Loss)')
    plt.xlabel('Epoch Number')
    plt.grid(True)
    plt.legend(['error(train)', 'error(valid)'], loc='upper left')
    plt.show()
    #Save visualization data    
    accuracy_plot.savefig(accuracy_grap_file, bbox_inches='tight')
    loss_plot.savefig(loss_graph_file, bbox_inches='tight')

# %%
def evaluateClassifier(history, classifier, weights, X ,y , cm_file, out_file, classlabels):
    classifier.load_weights(weights)
    y_pred = classifier.predict(X)
    cm = confusion_matrix(np.argmax(y,axis=1), np.argmax(np.rint(y_pred),axis=1))
    cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]
    plot = plot_confusion_matrix(cm_norm, classes=classlabels)
    plot.savefig(cm_file, bbox_inches='tight')
    scores = classifier.evaluate(X_valid,y_valid)
    with open(out_file, 'w') as the_file:
        the_file.write("Max Val Acc: " + str(np.max(np.array(history['val_acc']))))
        the_file.write("\nMin Val Acc: " + str(np.min(np.array(history['val_acc']))))
        the_file.write("\nMax Train Acc: "  + str(np.max(np.array(history['acc']))))
        the_file.write("\nMin Train Acc: "  + str(np.min(np.array(history['acc']))))
        the_file.write("\nMax Val Err: "  + str(np.max(np.array(history['val_loss']))))
        the_file.write("\nMin Val Err: " + str(np.min(np.array(history['val_loss']))))
        the_file.write("\nMax Train Err: " + str(np.max(np.array(history['loss']))))
        the_file.write("\nMin Train Err: " +  str(np.min(np.array(history['loss']))))
        the_file.write("\nResult: " + str(scores))
        the_file.write("\nResult: " +  str(model.metrics_names))

# %% [markdown]
# # Training & Visualizing & Evaluating

# %%
for i in range(1,6):
    print("Running Experiment Iteration",i)
    model = InceptionNet()
    #Process filenames
    prefix = "run#{}_".format(i)
    MODEL_CHECKPOINT_FILE=prefix + "experiment2-inception3-weights.hdf5"  
    #Training charts and graphics
    MODEL_TRAIN_RESULTS_FILE=prefix + "experiment2-inception3_train.pickle"
    MODEL_ACCURACY_GRAPH_FILE=prefix + "experiment2-inception3_accuracy.pdf"
    MODEL_LOSS_GRAPH_FILE=prefix + "experiment2-inception3_loss.pdf"
    MODEL_EVALUATION_CM_FILE=prefix + "experiment2-inception3_CM.pdf"
    MODEL_EVALUATION_TEXT_FILE=prefix + "experiment2-inception3_eval.txt"
    
    checkpoint = ModelCheckpoint(MODEL_CHECKPOINT_FILE, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    #Training
    history = model.fit(x=X_train,y=y_train,
                        validation_data=(X_valid,y_valid),
                        batch_size=BATCH_SIZE,
                        epochs = EPOCH,
                        callbacks = callbacks_list)
    
    #Saving training result
    with open(MODEL_TRAIN_RESULTS_FILE, "wb") as output_file:
        pickle.dump(history.history, output_file)    
    
    #Generate training graphs
    generateTrainingPlots(history.history, MODEL_ACCURACY_GRAPH_FILE, MODEL_LOSS_GRAPH_FILE)
    
    #evaluate classifier
    evaluateClassifier(history.history, InceptionNet(), MODEL_CHECKPOINT_FILE, 
                       X_valid ,y_valid , MODEL_EVALUATION_CM_FILE, MODEL_EVALUATION_TEXT_FILE, CLASS_LABELS)
    del model
# Out:
# Running Experiment Iteration 1
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 5252 samples, validate on 1735 samples
# Epoch 1/20
# 5252/5252 [==============================] - 134s 26ms/step - loss: 0.4274 - acc: 0.8046 - val_loss: 1.0161 - val_acc: 0.6571
#
# Epoch 00001: val_acc improved from -inf to 0.65706, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 2/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.2199 - acc: 0.9132 - val_loss: 1.1721 - val_acc: 0.6450
#
# Epoch 00002: val_acc did not improve
# Epoch 3/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.2182 - acc: 0.9111 - val_loss: 0.5475 - val_acc: 0.7718
#
# Epoch 00003: val_acc improved from 0.65706 to 0.77176, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 4/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1058 - acc: 0.9608 - val_loss: 2.1114 - val_acc: 0.6599
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0701 - acc: 0.9751 - val_loss: 1.6986 - val_acc: 0.6726
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0886 - acc: 0.9646 - val_loss: 0.9486 - val_acc: 0.7637
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0867 - acc: 0.9669 - val_loss: 1.0461 - val_acc: 0.7556
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0366 - acc: 0.9874 - val_loss: 1.4021 - val_acc: 0.7193
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1156 - acc: 0.9579 - val_loss: 0.7290 - val_acc: 0.7602
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0603 - acc: 0.9794 - val_loss: 0.7811 - val_acc: 0.7821
#
# Epoch 00010: val_acc improved from 0.77176 to 0.78213, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 11/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0240 - acc: 0.9922 - val_loss: 1.1094 - val_acc: 0.7591
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0525 - acc: 0.9810 - val_loss: 1.3109 - val_acc: 0.6916
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0869 - acc: 0.9716 - val_loss: 0.7463 - val_acc: 0.7821
#
# Epoch 00013: val_acc improved from 0.78213 to 0.78213, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 14/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0489 - acc: 0.9836 - val_loss: 1.0869 - val_acc: 0.7850
#
# Epoch 00014: val_acc improved from 0.78213 to 0.78501, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 15/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0110 - acc: 0.9970 - val_loss: 1.8017 - val_acc: 0.7268
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0121 - acc: 0.9964 - val_loss: 1.3137 - val_acc: 0.7677
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0060 - acc: 0.9985 - val_loss: 1.0623 - val_acc: 0.8029
#
# Epoch 00017: val_acc improved from 0.78501 to 0.80288, saving model to run#1_experiment2-inception3-weights.hdf5
# Epoch 18/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0073 - acc: 0.9977 - val_loss: 0.9181 - val_acc: 0.7925
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0074 - acc: 0.9987 - val_loss: 1.1048 - val_acc: 0.7844
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0449 - acc: 0.9869 - val_loss: 2.1337 - val_acc: 0.7222
#
# Epoch 00020: val_acc did not improve
# 1735/1735 [==============================] - 15s 8ms/step
# Running Experiment Iteration 2
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 5252 samples, validate on 1735 samples
# Epoch 1/20
# 5252/5252 [==============================] - 135s 26ms/step - loss: 0.4513 - acc: 0.8005 - val_loss: 1.9242 - val_acc: 0.3873
#
# Epoch 00001: val_acc improved from -inf to 0.38732, saving model to run#2_experiment2-inception3-weights.hdf5
# Epoch 2/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.2614 - acc: 0.8865 - val_loss: 0.9826 - val_acc: 0.7026
#
# Epoch 00002: val_acc improved from 0.38732 to 0.70259, saving model to run#2_experiment2-inception3-weights.hdf5
# Epoch 3/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1732 - acc: 0.9335 - val_loss: 1.1573 - val_acc: 0.6870
#
# Epoch 00003: val_acc did not improve
# Epoch 4/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1177 - acc: 0.9518 - val_loss: 1.0410 - val_acc: 0.7378
#
# Epoch 00004: val_acc improved from 0.70259 to 0.73775, saving model to run#2_experiment2-inception3-weights.hdf5
# Epoch 5/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0626 - acc: 0.9785 - val_loss: 1.2514 - val_acc: 0.7210
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1624 - acc: 0.9421 - val_loss: 0.7951 - val_acc: 0.7919
#
# Epoch 00006: val_acc improved from 0.73775 to 0.79193, saving model to run#2_experiment2-inception3-weights.hdf5
# Epoch 7/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0575 - acc: 0.9836 - val_loss: 1.7490 - val_acc: 0.6818
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0368 - acc: 0.9867 - val_loss: 1.3759 - val_acc: 0.7262
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0448 - acc: 0.9855 - val_loss: 2.0492 - val_acc: 0.6980
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0563 - acc: 0.9792 - val_loss: 1.7348 - val_acc: 0.7378
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1051 - acc: 0.9631 - val_loss: 1.6288 - val_acc: 0.6865
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0319 - acc: 0.9888 - val_loss: 0.7643 - val_acc: 0.8150
#
# Epoch 00012: val_acc improved from 0.79193 to 0.81499, saving model to run#2_experiment2-inception3-weights.hdf5
# Epoch 13/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0180 - acc: 0.9930 - val_loss: 1.3229 - val_acc: 0.7695
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0212 - acc: 0.9939 - val_loss: 0.9325 - val_acc: 0.7983
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0306 - acc: 0.9901 - val_loss: 1.5439 - val_acc: 0.6576
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0184 - acc: 0.9930 - val_loss: 1.1803 - val_acc: 0.7764
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0105 - acc: 0.9962 - val_loss: 1.7466 - val_acc: 0.7222
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0888 - acc: 0.9726 - val_loss: 0.7151 - val_acc: 0.7867
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0229 - acc: 0.9930 - val_loss: 1.0906 - val_acc: 0.7700
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0162 - acc: 0.9943 - val_loss: 1.8399 - val_acc: 0.7349
#
# Epoch 00020: val_acc did not improve
# 1735/1735 [==============================] - 16s 9ms/step
# Running Experiment Iteration 3
# Train on 5252 samples, validate on 1735 samples
# Epoch 1/20
# 5252/5252 [==============================] - 139s 27ms/step - loss: 0.4608 - acc: 0.7850 - val_loss: 2.0779 - val_acc: 0.6945
#
# Epoch 00001: val_acc improved from -inf to 0.69452, saving model to run#3_experiment2-inception3-weights.hdf5
# Epoch 2/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.2824 - acc: 0.8840 - val_loss: 1.4936 - val_acc: 0.6046
#
# Epoch 00002: val_acc did not improve
# Epoch 3/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.2443 - acc: 0.9037 - val_loss: 0.7575 - val_acc: 0.7493
#
# Epoch 00003: val_acc improved from 0.69452 to 0.74928, saving model to run#3_experiment2-inception3-weights.hdf5
# Epoch 4/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1770 - acc: 0.9334 - val_loss: 1.5423 - val_acc: 0.6697
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1059 - acc: 0.9612 - val_loss: 1.7349 - val_acc: 0.7020
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0706 - acc: 0.9768 - val_loss: 0.9366 - val_acc: 0.7545
#
# Epoch 00006: val_acc improved from 0.74928 to 0.75447, saving model to run#3_experiment2-inception3-weights.hdf5
# Epoch 7/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0531 - acc: 0.9804 - val_loss: 1.7475 - val_acc: 0.6611
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0524 - acc: 0.9851 - val_loss: 4.2712 - val_acc: 0.6455
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0528 - acc: 0.9802 - val_loss: 2.0062 - val_acc: 0.6928
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1831 - acc: 0.9303 - val_loss: 0.7484 - val_acc: 0.7274
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0957 - acc: 0.9659 - val_loss: 1.0904 - val_acc: 0.7568
#
# Epoch 00011: val_acc improved from 0.75447 to 0.75677, saving model to run#3_experiment2-inception3-weights.hdf5
# Epoch 12/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0800 - acc: 0.9705 - val_loss: 0.9215 - val_acc: 0.7833
#
# Epoch 00012: val_acc improved from 0.75677 to 0.78329, saving model to run#3_experiment2-inception3-weights.hdf5
# Epoch 13/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0272 - acc: 0.9916 - val_loss: 1.7379 - val_acc: 0.7187
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0475 - acc: 0.9832 - val_loss: 1.7208 - val_acc: 0.7297
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1503 - acc: 0.9480 - val_loss: 1.2655 - val_acc: 0.7303
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0406 - acc: 0.9867 - val_loss: 1.0506 - val_acc: 0.7648
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0569 - acc: 0.9819 - val_loss: 1.1883 - val_acc: 0.7579
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0375 - acc: 0.9899 - val_loss: 1.4544 - val_acc: 0.6599
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.3298 - acc: 0.8728 - val_loss: 0.9343 - val_acc: 0.7199
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.1181 - acc: 0.9581 - val_loss: 1.0090 - val_acc: 0.6905
#
# Epoch 00020: val_acc did not improve
# 1735/1735 [==============================] - 18s 11ms/step
# Running Experiment Iteration 4
# Train on 5252 samples, validate on 1735 samples
# Epoch 1/20
# 5252/5252 [==============================] - 144s 27ms/step - loss: 0.4752 - acc: 0.7848 - val_loss: 1.1090 - val_acc: 0.6444
#
# Epoch 00001: val_acc improved from -inf to 0.64438, saving model to run#4_experiment2-inception3-weights.hdf5
# Epoch 2/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.2705 - acc: 0.8865 - val_loss: 0.5865 - val_acc: 0.7850
#
# Epoch 00002: val_acc improved from 0.64438 to 0.78501, saving model to run#4_experiment2-inception3-weights.hdf5
# Epoch 3/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1622 - acc: 0.9337 - val_loss: 0.7533 - val_acc: 0.7147
#
# Epoch 00003: val_acc did not improve
# Epoch 4/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1109 - acc: 0.9602 - val_loss: 1.0239 - val_acc: 0.6749
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1644 - acc: 0.9370 - val_loss: 0.7110 - val_acc: 0.7435
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1401 - acc: 0.9457 - val_loss: 1.2143 - val_acc: 0.7343
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0509 - acc: 0.9813 - val_loss: 1.3280 - val_acc: 0.7545
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0601 - acc: 0.9791 - val_loss: 1.7525 - val_acc: 0.6951
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0369 - acc: 0.9882 - val_loss: 1.1126 - val_acc: 0.7418
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0418 - acc: 0.9853 - val_loss: 1.1896 - val_acc: 0.7666
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0545 - acc: 0.9829 - val_loss: 0.7569 - val_acc: 0.8029
#
# Epoch 00011: val_acc improved from 0.78501 to 0.80288, saving model to run#4_experiment2-inception3-weights.hdf5
# Epoch 12/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0393 - acc: 0.9884 - val_loss: 1.1278 - val_acc: 0.7758
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0204 - acc: 0.9945 - val_loss: 0.7421 - val_acc: 0.7983
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0366 - acc: 0.9880 - val_loss: 1.0443 - val_acc: 0.7735
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0184 - acc: 0.9928 - val_loss: 1.1372 - val_acc: 0.7735
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0891 - acc: 0.9722 - val_loss: 2.0235 - val_acc: 0.6991
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0167 - acc: 0.9952 - val_loss: 0.8609 - val_acc: 0.7960
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0121 - acc: 0.9954 - val_loss: 2.2210 - val_acc: 0.7072
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 5252/5252 [==============================] - 126s 24ms/step - loss: 0.0137 - acc: 0.9941 - val_loss: 1.0664 - val_acc: 0.7994
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0541 - acc: 0.9823 - val_loss: 1.4250 - val_acc: 0.7527
#
# Epoch 00020: val_acc did not improve
# 1735/1735 [==============================] - 21s 12ms/step
# Running Experiment Iteration 5
# Train on 5252 samples, validate on 1735 samples
# Epoch 1/20
# 5252/5252 [==============================] - 149s 28ms/step - loss: 0.4579 - acc: 0.8014 - val_loss: 0.9984 - val_acc: 0.5781
#
# Epoch 00001: val_acc improved from -inf to 0.57810, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 2/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.2341 - acc: 0.9042 - val_loss: 0.8165 - val_acc: 0.6617
#
# Epoch 00002: val_acc improved from 0.57810 to 0.66167, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 3/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1383 - acc: 0.9463 - val_loss: 1.0469 - val_acc: 0.7602
#
# Epoch 00003: val_acc improved from 0.66167 to 0.76023, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 4/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0785 - acc: 0.9718 - val_loss: 1.4429 - val_acc: 0.6974
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0594 - acc: 0.9779 - val_loss: 0.9697 - val_acc: 0.7378
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0949 - acc: 0.9646 - val_loss: 0.8114 - val_acc: 0.7637
#
# Epoch 00006: val_acc improved from 0.76023 to 0.76369, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 7/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1220 - acc: 0.9566 - val_loss: 0.7953 - val_acc: 0.7971
#
# Epoch 00007: val_acc improved from 0.76369 to 0.79712, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 8/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0932 - acc: 0.9686 - val_loss: 0.7158 - val_acc: 0.7614
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0253 - acc: 0.9924 - val_loss: 0.9513 - val_acc: 0.7919
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0631 - acc: 0.9789 - val_loss: 0.8610 - val_acc: 0.7337
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.1126 - acc: 0.9615 - val_loss: 1.6944 - val_acc: 0.6818
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0307 - acc: 0.9895 - val_loss: 1.1644 - val_acc: 0.7516
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0168 - acc: 0.9943 - val_loss: 1.2731 - val_acc: 0.7643
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0176 - acc: 0.9939 - val_loss: 1.8025 - val_acc: 0.7268
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0114 - acc: 0.9956 - val_loss: 0.8682 - val_acc: 0.8017
#
# Epoch 00015: val_acc improved from 0.79712 to 0.80173, saving model to run#5_experiment2-inception3-weights.hdf5
# Epoch 16/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0121 - acc: 0.9954 - val_loss: 1.2321 - val_acc: 0.7769
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0158 - acc: 0.9947 - val_loss: 2.0471 - val_acc: 0.7401
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0099 - acc: 0.9960 - val_loss: 1.4045 - val_acc: 0.7654
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0104 - acc: 0.9954 - val_loss: 1.8657 - val_acc: 0.7003
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 5252/5252 [==============================] - 127s 24ms/step - loss: 0.0122 - acc: 0.9970 - val_loss: 1.6463 - val_acc: 0.7452
#
# Epoch 00020: val_acc did not improve
# 1735/1735 [==============================] - 23s 13ms/step

# %%
print("Completed")
# Out:
# Completed
