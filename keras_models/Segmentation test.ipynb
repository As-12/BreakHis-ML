# %%
# set the matplotlib backend so figures can be saved in the background
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import matplotlib
import keras
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2

import shutil
import fnmatch
import pickle
from keras import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Input
from keras.constraints import max_norm
from keras import regularizers
from keras.layers.advanced_activations import LeakyReLU
import keras.initializers
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import keras.optimizers
from keras.utils import np_utils
from keras import backend as K
from keras.applications.inception_v3 import InceptionV3

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import imgaug as ia
from imgaug import augmenters as iaa

TRAIN_DIR = '../TRAIN'
# Out:
# /home/as12production/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def buildImageDataset(path, imageResize=None,shuffle=False,seed=0):
    """
    Load dataset into an array. Labels are defined by folder name.
    """
    filenames = []
    data = []
    labels = []
    imagePaths = sorted(list(paths.list_images(path)))
    
    if shuffle == True:
        random.seed(seed)
        random.shuffle(imagePaths)
    
    for imagePath in imagePaths:
        if "-100-" not in imagePath:
            continue
        print(imagePath)
        image = cv2.imread(imagePath)
        
        if imageResize != None:
            image = cv2.resize(image, imageResize)
        image = img_to_array(image)
        data.append(image)
        filenames.append(imagePath)
        label = imagePath.split(os.path.sep)[-2]
        labels.append(CLASS_LABELS.index(label))
    return (np.array(data), np.array(labels), np.array(filenames))

def showClassDistribution(y, labels):
    figure = plt.figure(figsize=(10,5))
    ax = sns.countplot(x = y)
    ax.set_xticklabels(labels)
    plt.show()

def imageResizer(dataset, imageResize):
    result = []
    for image in dataset:
        result.append(ia.imresize_single_image(image, imageResize))
    return np.array(result)

# %%
#split images into regions

def splitImage(image, n_split):
    """
    Takes a numpy image matrix, and split them based into nxn matrix
    return numpy matrix (regions, rows, columns, channel)
    """
    import numpy as np
    
    #Calculate region width and height
    block_r = int(np.floor(image.shape[0] / n_split))
    block_c = int(np.floor(image.shape[1] / n_split))
    
    result = []
    
    #Split the image based on block_r and block_c, and append it to result array
    row = 0
    for _ in range(0,n_split-1):
        col = 0
        start_r = row  * block_r
        for _ in range(0,n_split-1):
            start_c = col  * block_c
            result.append(image[start_r:start_r + block_r, start_c:start_c + block_c,:])
            col += 1
        #Some images may not divide evenly, so use the remaining pixels on the last patch
        start_c = col * block_c
        result.append(image[start_r:start_r + block_r, start_c:,:])
        row += 1
    #Some images may not divide evenly, so use the remaining pixels on the last patch
    start_r = row  * block_r
    col = 0
    for _ in range(0,n_split-1):
        start_c = col  * block_c
        result.append(image[start_r:, start_c:start_c + block_c,:])
        col += 1
    #Some images may not divide evenly, so use the remaining pixels on the last patch
    start_c = col * block_c
    result.append(image[start_r:, start_c:, :])
    
    return np.array(result)


def isRegionOfInterest(image, threshold=(0.5,0.5,0.5), perecent_threshold=0.25):
    """
    Takes a numpy image matrix (row,col,channels) and associated threshold value for each channels.
    Return a copy of matrix with anything greater than or equal to threshold sets to 
    """
    import numpy as np
    
    def color_threshold(img, th):
        """
        Takes a numpy image matrix (row,col,channels) and associated threshold value for each channel. 
        Return a copy of matrix with anything greater than or equal to threshold sets to one and zero for everything else.
        """
        assert img.shape[2] == len(th), "number of channels must be equal to number of threshold"
        result = np.copy(img)
        for channel, value in enumerate(th):
            low_values_flags = result[:,:,channel] < value  # Where values are low
            high_values_flags = result[:,:,channel] >= value  # Where values are low
            result[low_values_flags,channel] = 1  # All low values set to 0
            result[high_values_flags,channel] = 0  # All low values set to 0
        return result

    def totalImageSize(patch):
        """
        Takes a numpy image matrix (row, col, channels) and return the total number of elements
        """
        size = 1
        for i in patch.shape:
            size *= i
        return size
    
    if ( float(np.sum(color_threshold(image, threshold))) / totalImageSize(image)) > float(perecent_threshold):
        return True
    else:
        return False

# %%
path =  '../TEST'
CLASS_LABELS = ["Benign", "Malignant"]
set_of_images,_,_ = buildImageDataset(path, imageResize=None,shuffle=False,seed=0)
print(set_of_images.shape)
# Out:
# ../TEST/Benign/SOB_B_A-14-22549CD-100-001.png
# ../TEST/Benign/SOB_B_A-14-22549CD-100
# ../TEST/Benign/SOB_B_TA-14-19854C-100-016.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-001.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-003.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-004.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-005.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-006.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-007.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-008.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-009.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-010.png
# ../TEST/Malignant/SOB_M_DC-14-16601-100-011.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-001.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-002.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-003.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-004.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-005.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-006.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-007.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-008.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-009.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-010.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-011.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-012.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-013.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-014.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-015.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-016.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-017.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-018.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-019.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-020.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-021.png
# ../TEST/Malignant/SOB_M_DC-14-16875-100-022.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-001.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-002.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-003.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-004.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-005.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-006.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-007.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-008.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-009.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-010.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-011.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-012.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-013.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-014.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-015.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-016.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-017.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-018.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-019.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-020.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-021.png
# ../TEST/Malignant/SOB_M_DC-14-18650-100-022.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-001.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-002.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-003.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-004.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-005.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-006.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-007.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-008.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-009.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-010.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-011.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-012.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-013.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-014.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-015.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-016.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-017.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-018.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-019.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-020.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-021.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-022.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-023.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-024.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-025.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-026.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-027.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-028.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-029.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-030.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-031.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-032.png
# ../TEST/Malignant/SOB_M_LC-14-13412-100-033.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-001.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-002.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-003.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-004.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-005.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-006.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-007.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-008.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-009.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-010.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-011.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-012.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-013.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-014.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-015.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-016.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-017.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-018.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-019.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-020.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-021.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-023.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-024.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-025.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-026.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-027.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-028.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-029.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-030.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-031.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-032.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-033.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-034.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-035.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-036.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-037.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-038.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-039.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-040.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-041.png
# ../TEST/Malignant/SOB_M_MC-14-13413-100-042.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-001.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-002.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-003.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-004.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-005.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-006.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-007.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-008.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-009.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-010.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-011.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-012.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-013.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-014.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-015.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-016.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-017.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-018.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-019.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-020.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-021.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-022.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-023.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-024.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-025.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-026.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-027.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-028.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-029.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-030.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-031.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-032.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-033.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-034.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-035.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-036.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-037.png
# ../TEST/Malignant/SOB_M_PC-14-19440-100-038.png
# (250, 460, 700, 3)

# %%
a = np.array([1,2,1,2])
np.argmax(a)
# Out:
# 1

# %%
# Hyper-parameter

#set_of_images /= 255.0

early_stop = 1

for index, image in enumerate(set_of_images):
    if index >= early_stop:
        break
    plt.imshow(image)
    plt.show()
    for patch in splitImage(image,6):
        plt.imshow(patch)
        plt.show()

# %%
set_of_images /= 255

# %%
early_stop = 5000
cell = []
not_cell = []

for index, image in enumerate(set_of_images):
    #if index >= early_stop:
      #  break
    for patch in splitImage(image,9):
        if (isRegionOfInterest(patch, threshold=(0.2,0.2,0.2), perecent_threshold=0.01)):
            cell.append(patch)
        else:
            not_cell.append(patch)


cell = np.array(cell)
not_cell = np.array(not_cell)

# %%
print(set_of_images.shape)
print(cell.shape)
print(not_cell.shape)
# Out:
# (250, 460, 700, 3)
# (764,)
# (19486,)

# %%
# !rm cell/*
# !rm not_cell/*

# %%
import scipy.misc

max_write = 10


for i,img in enumerate(cell): 
    if i > max_write:
        break
    scipy.misc.imsave('cell/'+str(i)+'.jpg', img)

for i,img in enumerate(not_cell): 
    if i > max_write:
        break
    scipy.misc.imsave('not_cell/'+str(i)+'.jpg', img)
# Out:
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
#   if __name__ == '__main__':
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
