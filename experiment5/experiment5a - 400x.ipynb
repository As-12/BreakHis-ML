# %% [markdown]
# # MLP-CW4 Experiment 5a 400x  execution notebook
#
# This notebook is not for data exploration. But to log execution of experiments.
#
# Experiment 5a
#  - per magnification, augment data on rotation, horizontal, and vertical flip

# %% [markdown]
# ## Imports

# %%
# set the matplotlib backend so figures can be saved in the background
import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
import matplotlib
import keras
# import the necessary packages
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.utils import to_categorical
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import random
import cv2

import shutil
import fnmatch
import pickle
from keras import Model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.layers import Input
from keras.constraints import max_norm
from keras import regularizers
from keras.layers.advanced_activations import LeakyReLU
import keras.initializers
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
import keras.optimizers
from keras.utils import np_utils
from keras import backend as K
from keras.applications.inception_v3 import InceptionV3

from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import imgaug as ia
from imgaug import augmenters as iaa
# Out:
# /home/as12production/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Environment Settings

# %%
#Keras setting
K.set_image_dim_ordering('tf')  #Image dimension ordering

#Random seeds
SEED = 2082018
np.random.seed(SEED)

#Image Settings
IMAGE_RESIZE = (224,224)  # Image size. Process on the by data generator. Should match CNN model input. 
IMAGE_INPUT_SIZE = (224,224,3) #Image Input size to the neural network

#Training Settings
BATCH_SIZE = 32
EPOCH = 20

#Directories
# NOTE: The labels are determined by subfolders. PNG or JPEG images only.
TRAIN_DIR = '../TRAIN' 
VAL_DIR = '../VALID'
TEST_DIR =  '../TEST'


#["-40","-100-","-200-","-400-"]
magnifications = "-400-"
experiment_name = "experiment5a"

#Index of the class label represents numerical representation
CLASS_LABELS = ["Benign", "Malignant"]
NUM_CLASSES = 2
#Checkpoints and save files

#Saving every epochs that improve val accuracy
#MODEL_CHECKPOINT_FILE="baseline_model-weights-{epoch:02d}-{val_acc:.2f}.hdf5"
# Rewriting save file for epoch that improves val accuracy
MODEL_CHECKPOINT_FILE="inception3-weights.hdf5"  

#Training charts and graphics
MODEL_TRAIN_RESULTS_FILE="inception3_train.pickle"
MODEL_ACCURACY_GRAPH_FILE="inception3_accuracy.pdf"
MODEL_LOSS_GRAPH_FILE="inception3_loss.pdf"
MODEL_EVALUATION_CM_FILE="inception3_CM.pdf"

# %% [markdown]
# ## Loading Dataset

# %%
def buildImageDataset(path, imageResize=None,shuffle=False,seed=0):
    """
    Load dataset into an array. Labels are defined by folder name.
    """
    filenames = []
    data = []
    labels = []
    imagePaths = sorted(list(paths.list_images(path)))
    
    if shuffle == True:
        random.seed(seed)
        random.shuffle(imagePaths)

    for imagePath in imagePaths:
        image = cv2.imread(imagePath)
        if imageResize != None:
            image = cv2.resize(image, imageResize)
        image = img_to_array(image)
        data.append(image)
        filenames.append(imagePath)
        label = imagePath.split(os.path.sep)[-2]
        labels.append(CLASS_LABELS.index(label))
    return (np.array(data), np.array(labels), np.array(filenames))

def showClassDistribution(y, labels):
    figure = plt.figure(figsize=(10,5))
    ax = sns.countplot(x = y)
    ax.set_xticklabels(labels)
    plt.show()

# %%
run_this = 1

# Load and save
if run_this == 1:
    X_train, y_train, train_files = buildImageDataset(TRAIN_DIR,imageResize=IMAGE_RESIZE,seed=SEED)
    X_valid, y_valid, valid_files = buildImageDataset(VAL_DIR,imageResize=IMAGE_RESIZE,seed=SEED)

# %%
run_this = 1

if run_this == 1:
    validDataFrame = pd.DataFrame({'label':y_valid, 'filename':valid_files})
    trainDataFrame = pd.DataFrame({'label':y_train, 'filename':train_files})
    
    index = [i for i,item in enumerate(trainDataFrame["filename"]) if magnifications in item]
    X_train = X_train[index]
    y_train = y_train[index]
    train_files = train_files[index]
    
    index = [i for i,item in enumerate(validDataFrame["filename"]) if magnifications in item]
    X_valid = X_valid[index]
    y_valid = y_valid[index]
    valid_files = valid_files[index]

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax1.imshow(X_train[-1])
ax2 = fig.add_subplot(2,2,2)
ax2.imshow(X_train[1])
ax3 = fig.add_subplot(2,2,3)
ax3.imshow(X_valid[-1])
ax4 = fig.add_subplot(2,2,4)
ax4.imshow(X_valid[1])

fig.savefig("rescaled"+magnifications+"images.pdf")

# %%
trainDataFrame = pd.DataFrame({'label':y_train, 'filename':train_files})
showClassDistribution(y_train, CLASS_LABELS)
print("There are {} items in training set.".format(len(y_train) ))
# Out:
# There are 1198 items in training set.

# %%
validDataFrame = pd.DataFrame({'label':y_valid, 'filename':valid_files})
showClassDistribution(y_valid, CLASS_LABELS)
print("There are {} items in validation set.".format(len(y_valid) ))
# Out:
# There are 403 items in validation set.

# %% [markdown]
# # Augmentation

# %%
run_this = 1

if run_this == 1:
    LR = iaa.Sequential([iaa.Fliplr(1)])
    UD = iaa.Sequential([iaa.Fliplr(1)])
    RT90 = iaa.Sequential([iaa.Affine(rotate=90)])
    RT180 = iaa.Sequential([iaa.Affine(rotate=180)])
    RT270 = iaa.Sequential([iaa.Affine(rotate=270)])
    images_aug1 = LR.augment_images(X_train)
    images_aug2 = UD.augment_images(X_train)
    images_aug3 = RT90.augment_images(X_train)
    images_aug4 = RT180.augment_images(X_train)
    images_aug5 = RT270.augment_images(X_train)
    X_train = np.vstack((np.vstack((
                     np.vstack((
                         np.vstack((
                             np.vstack((images_aug1,images_aug2)),images_aug3)),images_aug4)),images_aug5)),X_train))
    y_temp = np.array([])
    for i in range(6):
        y_temp = np.concatenate((y_temp,y_train))
    y_train = y_temp

# %% [markdown]
# ## Pre-Processing

# %%
X_train /= 255.0
X_valid /= 255.0
y_train = keras.utils.to_categorical(y_train)
y_valid = keras.utils.to_categorical(y_valid)

# %% [markdown]
# # Building Neural Net Model

# %%
# Building Models
def InceptionNet():
    #https://keras.io/applications/#inceptionv3
    #Use Inception 3 without the last layer.
    #Replace last layer with 1 sigmoid for binary classification
    sgd = SGD(lr=0.01, momentum=0.9,nesterov=False)
    model = keras.applications.inception_v3.InceptionV3(include_top=False,
                                                        weights='imagenet',  #Pre-train on ImageNet 
                                                        input_tensor=Input(shape=IMAGE_INPUT_SIZE),
                                                        input_shape=None,
                                                        pooling='avg',
                                                        classes=NUM_CLASSES)
    final = Model(input=model.input,output=Dense(NUM_CLASSES, activation='softmax')(model.output))
    final.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])    
    return final

# %% [markdown]
# # Required Function Definitions

# %%
def plot_confusion_matrix(cm, classes=None, title='Confusion matrix'):
    """Plots a confusion matrix."""
    plot = plt.figure()
    if classes is not None:
        sns.heatmap(cm, xticklabels=classes, yticklabels=classes, vmin=0., vmax=1., annot=True)
    else:
        sns.heatmap(cm, vmin=0., vmax=1.)
    plt.title(title)
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    return plot

# %%
def generateTrainingPlots(history, accuracy_grap_file, loss_graph_file):
    plt.style.use('ggplot')
    accuracy_plot = plt.figure(figsize=(15,10))
    for k in ['val_acc', 'acc']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch Number')
    plt.ylim((0,1.2))
    plt.legend(['acc(valid)', 'acc(train)'], loc='upper left')
    plt.grid(True)
    plt.show()
    loss_plot = plt.figure(figsize=(15,10))
    for k in ['loss', 'val_loss']:
        data = np.array(history[k])
        plt.plot(data)
    plt.title('Model Loss')
    plt.ylabel('Error (Log Loss)')
    plt.xlabel('Epoch Number')
    plt.grid(True)
    plt.legend(['error(train)', 'error(valid)'], loc='upper left')
    plt.show()
    #Save visualization data    
    accuracy_plot.savefig(accuracy_grap_file, bbox_inches='tight')
    loss_plot.savefig(loss_graph_file, bbox_inches='tight')

# %%
def evaluateClassifier(history, classifier, weights, X ,y , cm_file, out_file, classlabels):
    classifier.load_weights(weights)
    y_pred = classifier.predict(X)
    cm = confusion_matrix(np.argmax(y,axis=1), np.argmax(np.rint(y_pred),axis=1))
    cm_norm = cm/cm.sum(axis=1)[:, np.newaxis]
    plot = plot_confusion_matrix(cm_norm, classes=classlabels)
    plot.savefig(cm_file, bbox_inches='tight')
    scores = classifier.evaluate(X_valid,y_valid)
    with open(out_file, 'w') as the_file:
        the_file.write("Max Val Acc: " + str(np.max(np.array(history['val_acc']))))
        the_file.write("\nMin Val Acc: " + str(np.min(np.array(history['val_acc']))))
        the_file.write("\nMax Train Acc: "  + str(np.max(np.array(history['acc']))))
        the_file.write("\nMin Train Acc: "  + str(np.min(np.array(history['acc']))))
        the_file.write("\nMax Val Err: "  + str(np.max(np.array(history['val_loss']))))
        the_file.write("\nMin Val Err: " + str(np.min(np.array(history['val_loss']))))
        the_file.write("\nMax Train Err: " + str(np.max(np.array(history['loss']))))
        the_file.write("\nMin Train Err: " +  str(np.min(np.array(history['loss']))))
        the_file.write("\nResult: " + str(scores))
        the_file.write("\nResult: " +  str(model.metrics_names))

# %% [markdown]
# # Training & Visualizing & Evaluating

# %%
for i in range(1,4):
    print("Running Experiment Iteration",i)
    model = InceptionNet()
    #Process filenames
    prefix = "run#{}_".format(i)
    MODEL_CHECKPOINT_FILE=prefix + experiment_name + magnifications+"inception3-weights.hdf5"  
    #Training charts and graphics
    MODEL_TRAIN_RESULTS_FILE=prefix + experiment_name + magnifications+"inception3_train.pickle"
    MODEL_ACCURACY_GRAPH_FILE=prefix + experiment_name + magnifications+"inception3_accuracy.pdf"
    MODEL_LOSS_GRAPH_FILE=prefix + experiment_name + magnifications+"inception3_loss.pdf"
    MODEL_EVALUATION_CM_FILE=prefix + experiment_name + magnifications+"inception3_CM.pdf"
    MODEL_EVALUATION_TEXT_FILE=prefix + experiment_name + magnifications+"inception3_eval.txt"
    
    checkpoint = ModelCheckpoint(MODEL_CHECKPOINT_FILE, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    
    #Training
    history = model.fit(x=X_train,y=y_train,
                        validation_data=(X_valid,y_valid),
                        batch_size=BATCH_SIZE,
                        epochs = EPOCH,
                        callbacks = callbacks_list)
    
    #Saving training result
    with open(MODEL_TRAIN_RESULTS_FILE, "wb") as output_file:
        pickle.dump(history.history, output_file)    
    
    #Generate training graphs
    generateTrainingPlots(history.history, MODEL_ACCURACY_GRAPH_FILE, MODEL_LOSS_GRAPH_FILE)
    
    #evaluate classifier
    evaluateClassifier(history.history, InceptionNet(), MODEL_CHECKPOINT_FILE, 
                       X_valid ,y_valid , MODEL_EVALUATION_CM_FILE, MODEL_EVALUATION_TEXT_FILE, CLASS_LABELS)
    del model
# Out:
# Running Experiment Iteration 1
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 12s 0us/step
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 7188 samples, validate on 403 samples
# Epoch 1/20
# 7188/7188 [==============================] - 180s 25ms/step - loss: 0.2023 - acc: 0.9132 - val_loss: 1.9616 - val_acc: 0.7295
#
# Epoch 00001: val_acc improved from -inf to 0.72953, saving model to run#1_experiment5a-400-inception3-weights.hdf5
# Epoch 2/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0514 - acc: 0.9811 - val_loss: 1.5191 - val_acc: 0.7419
#
# Epoch 00002: val_acc improved from 0.72953 to 0.74194, saving model to run#1_experiment5a-400-inception3-weights.hdf5
# Epoch 3/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0243 - acc: 0.9928 - val_loss: 1.6334 - val_acc: 0.8164
#
# Epoch 00003: val_acc improved from 0.74194 to 0.81638, saving model to run#1_experiment5a-400-inception3-weights.hdf5
# Epoch 4/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0510 - acc: 0.9864 - val_loss: 1.8361 - val_acc: 0.7717
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0097 - acc: 0.9969 - val_loss: 1.7321 - val_acc: 0.8337
#
# Epoch 00005: val_acc improved from 0.81638 to 0.83375, saving model to run#1_experiment5a-400-inception3-weights.hdf5
# Epoch 6/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0323 - acc: 0.9911 - val_loss: 1.4608 - val_acc: 0.7146
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0059 - acc: 0.9985 - val_loss: 1.2600 - val_acc: 0.8065
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0016 - acc: 0.9997 - val_loss: 1.6196 - val_acc: 0.8015
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0012 - acc: 0.9996 - val_loss: 1.7519 - val_acc: 0.7940
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 6.1155e-04 - acc: 0.9999 - val_loss: 1.6961 - val_acc: 0.7990
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0042 - acc: 0.9985 - val_loss: 2.8278 - val_acc: 0.7221
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0062 - acc: 0.9982 - val_loss: 1.5230 - val_acc: 0.7593
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 9.2113e-04 - acc: 0.9999 - val_loss: 1.5174 - val_acc: 0.7767
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0029 - acc: 0.9993 - val_loss: 1.6772 - val_acc: 0.7320
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0103 - acc: 0.9972 - val_loss: 2.1240 - val_acc: 0.7543
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0106 - acc: 0.9968 - val_loss: 1.6874 - val_acc: 0.7717
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0113 - acc: 0.9972 - val_loss: 1.5917 - val_acc: 0.8313
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0043 - acc: 0.9986 - val_loss: 1.2061 - val_acc: 0.7965
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0040 - acc: 0.9990 - val_loss: 1.2317 - val_acc: 0.8089
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 3.0140e-04 - acc: 1.0000 - val_loss: 1.4311 - val_acc: 0.7965
#
# Epoch 00020: val_acc did not improve
# 403/403 [==============================] - 5s 12ms/step
# Running Experiment Iteration 2
# /home/as12production/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   del sys.path[0]
# Train on 7188 samples, validate on 403 samples
# Epoch 1/20
# 7188/7188 [==============================] - 166s 23ms/step - loss: 0.2060 - acc: 0.9153 - val_loss: 1.0141 - val_acc: 0.7171
#
# Epoch 00001: val_acc improved from -inf to 0.71712, saving model to run#2_experiment5a-400-inception3-weights.hdf5
# Epoch 2/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0562 - acc: 0.9786 - val_loss: 1.0403 - val_acc: 0.7643
#
# Epoch 00002: val_acc improved from 0.71712 to 0.76427, saving model to run#2_experiment5a-400-inception3-weights.hdf5
# Epoch 3/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0315 - acc: 0.9886 - val_loss: 1.3656 - val_acc: 0.8065
#
# Epoch 00003: val_acc improved from 0.76427 to 0.80645, saving model to run#2_experiment5a-400-inception3-weights.hdf5
# Epoch 4/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0189 - acc: 0.9939 - val_loss: 1.4141 - val_acc: 0.7916
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0183 - acc: 0.9942 - val_loss: 1.6089 - val_acc: 0.7568
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0071 - acc: 0.9976 - val_loss: 1.6757 - val_acc: 0.7767
#
# Epoch 00006: val_acc did not improve
# Epoch 7/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0059 - acc: 0.9976 - val_loss: 1.8072 - val_acc: 0.7295
#
# Epoch 00007: val_acc did not improve
# Epoch 8/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0041 - acc: 0.9986 - val_loss: 1.7705 - val_acc: 0.7568
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0045 - acc: 0.9987 - val_loss: 2.2740 - val_acc: 0.6849
#
# Epoch 00009: val_acc did not improve
# Epoch 10/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 0.0041 - acc: 0.9989 - val_loss: 2.0539 - val_acc: 0.7767
#
# Epoch 00010: val_acc did not improve
# Epoch 11/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0044 - acc: 0.9983 - val_loss: 1.9458 - val_acc: 0.7692
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 7188/7188 [==============================] - 157s 22ms/step - loss: 6.8095e-04 - acc: 0.9997 - val_loss: 1.5903 - val_acc: 0.7667
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 7.5363e-04 - acc: 0.9997 - val_loss: 1.9096 - val_acc: 0.7444
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0015 - acc: 0.9993 - val_loss: 1.9392 - val_acc: 0.7767
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0028 - acc: 0.9992 - val_loss: 1.5217 - val_acc: 0.7841
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0073 - acc: 0.9982 - val_loss: 2.9630 - val_acc: 0.6873
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0295 - acc: 0.9915 - val_loss: 2.1345 - val_acc: 0.7444
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0114 - acc: 0.9957 - val_loss: 1.7527 - val_acc: 0.7667
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0034 - acc: 0.9992 - val_loss: 1.9067 - val_acc: 0.7816
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 6.4875e-04 - acc: 1.0000 - val_loss: 1.7034 - val_acc: 0.7568
#
# Epoch 00020: val_acc did not improve
# 403/403 [==============================] - 7s 16ms/step
# Running Experiment Iteration 3
# Train on 7188 samples, validate on 403 samples
# Epoch 1/20
# 7188/7188 [==============================] - 171s 24ms/step - loss: 0.2024 - acc: 0.9160 - val_loss: 1.2138 - val_acc: 0.7345
#
# Epoch 00001: val_acc improved from -inf to 0.73449, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 2/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0475 - acc: 0.9830 - val_loss: 1.5260 - val_acc: 0.7047
#
# Epoch 00002: val_acc did not improve
# Epoch 3/20
# 7188/7188 [==============================] - 159s 22ms/step - loss: 0.0316 - acc: 0.9889 - val_loss: 1.9299 - val_acc: 0.7444
#
# Epoch 00003: val_acc improved from 0.73449 to 0.74442, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 4/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0138 - acc: 0.9961 - val_loss: 1.8244 - val_acc: 0.7270
#
# Epoch 00004: val_acc did not improve
# Epoch 5/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0127 - acc: 0.9976 - val_loss: 2.6195 - val_acc: 0.6675
#
# Epoch 00005: val_acc did not improve
# Epoch 6/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0312 - acc: 0.9901 - val_loss: 1.2859 - val_acc: 0.7519
#
# Epoch 00006: val_acc improved from 0.74442 to 0.75186, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 7/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0052 - acc: 0.9985 - val_loss: 1.2742 - val_acc: 0.7767
#
# Epoch 00007: val_acc improved from 0.75186 to 0.77667, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 8/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0047 - acc: 0.9983 - val_loss: 1.6583 - val_acc: 0.7221
#
# Epoch 00008: val_acc did not improve
# Epoch 9/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 0.0034 - acc: 0.9992 - val_loss: 1.2176 - val_acc: 0.7816
#
# Epoch 00009: val_acc improved from 0.77667 to 0.78164, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 10/20
# 7188/7188 [==============================] - 159s 22ms/step - loss: 0.0032 - acc: 0.9993 - val_loss: 1.4271 - val_acc: 0.8089
#
# Epoch 00010: val_acc improved from 0.78164 to 0.80893, saving model to run#3_experiment5a-400-inception3-weights.hdf5
# Epoch 11/20
# 7188/7188 [==============================] - 159s 22ms/step - loss: 0.0012 - acc: 0.9999 - val_loss: 1.4257 - val_acc: 0.7667
#
# Epoch 00011: val_acc did not improve
# Epoch 12/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 6.1071e-04 - acc: 1.0000 - val_loss: 1.4572 - val_acc: 0.7643
#
# Epoch 00012: val_acc did not improve
# Epoch 13/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 2.6430e-04 - acc: 1.0000 - val_loss: 1.4797 - val_acc: 0.7717
#
# Epoch 00013: val_acc did not improve
# Epoch 14/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 8.5464e-04 - acc: 0.9997 - val_loss: 1.4205 - val_acc: 0.7767
#
# Epoch 00014: val_acc did not improve
# Epoch 15/20
# 7188/7188 [==============================] - 159s 22ms/step - loss: 6.7970e-04 - acc: 1.0000 - val_loss: 1.5954 - val_acc: 0.7717
#
# Epoch 00015: val_acc did not improve
# Epoch 16/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 2.0711e-04 - acc: 1.0000 - val_loss: 1.5079 - val_acc: 0.7667
#
# Epoch 00016: val_acc did not improve
# Epoch 17/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 2.5707e-04 - acc: 1.0000 - val_loss: 1.4833 - val_acc: 0.7816
#
# Epoch 00017: val_acc did not improve
# Epoch 18/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 7.2724e-04 - acc: 0.9997 - val_loss: 1.6591 - val_acc: 0.7841
#
# Epoch 00018: val_acc did not improve
# Epoch 19/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 2.4209e-04 - acc: 1.0000 - val_loss: 1.6316 - val_acc: 0.7593
#
# Epoch 00019: val_acc did not improve
# Epoch 20/20
# 7188/7188 [==============================] - 158s 22ms/step - loss: 1.3911e-04 - acc: 1.0000 - val_loss: 1.7465 - val_acc: 0.7717
#
# Epoch 00020: val_acc did not improve
# 403/403 [==============================] - 8s 21ms/step

# %%
print("Completed")
# Out:
# Completed

# %%
# %%javascript
# Jupyter.notebook.session.delete();
